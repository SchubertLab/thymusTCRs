# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as pl
from matplotlib import rcParams
import scanpy as sc

# %%
path_tcr= '04_merged_data.h5ad'
adata = sc.read_h5ad(path_tcr)

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 76994 × 5000
# ...

# %%
sc.pl.highest_expr_genes(adata, n_top=20)

# %%
print(adata.obs.head(10))
# Out:
#                                      Sample donor organ sort method  \
# index
# FCAImmP7179369-AAACCTGAGCCCAATT  F21_TH_45P   F21    TH  45P   3GEX
# FCAImmP7179369-AAACCTGAGCCTATGT  F21_TH_45P   F21    TH  45P   3GEX
# FCAImmP7179369-AAACCTGAGTCGCCGT  F21_TH_45P   F21    TH  45P   3GEX
# FCAImmP7179369-AAACCTGCAGCATGAG  F21_TH_45P   F21    TH  45P   3GEX
# FCAImmP7179369-AAACCTGGTCTCCCTA  F21_TH_45P   F21    TH  45P   3GEX
# FCAImmP7179369-AAACCTGTCCCTTGCA  F21_TH_45P   F21    TH  45P   3GEX
# FCAImmP7179369-AAACGGGAGGACAGCT  F21_TH_45P   F21    TH  45P   3GEX
# FCAImmP7179369-AAACGGGAGGAGCGTT  F21_TH_45P   F21    TH  45P   3GEX
# FCAImmP7179369-AAACGGGAGTCATGCT  F21_TH_45P   F21    TH  45P   3GEX
# FCAImmP7179369-AAACGGGCAAGTAGTA  F21_TH_45P   F21    TH  45P   3GEX
#
#                                            file  is_TRA_p  is_TRB_p  \
# index
# FCAImmP7179369-AAACCTGAGCCCAATT  FCAImmP7179369     False     False
# ...

# %%
print('Amount cells: ', adata.X.shape[0])
print('Amount genes: ', adata.X.shape[1])
# Out:
# Amount cells:  76994
# Amount genes:  5000

# %%
print('Annotations per Cell: ')
adata.var_names_make_unique()
adata.obs.head(5)
# Out:
# Annotations per Cell:
#                                      Sample donor organ sort method  \
# index
# FCAImmP7179369-AAACCTGAGCCCAATT  F21_TH_45P   F21    TH  45P   3GEX
# FCAImmP7179369-AAACCTGAGCCTATGT  F21_TH_45P   F21    TH  45P   3GEX
# FCAImmP7179369-AAACCTGAGTCGCCGT  F21_TH_45P   F21    TH  45P   3GEX
# FCAImmP7179369-AAACCTGCAGCATGAG  F21_TH_45P   F21    TH  45P   3GEX
# FCAImmP7179369-AAACCTGGTCTCCCTA  F21_TH_45P   F21    TH  45P   3GEX
#
#                                            file  is_TRA_p  is_TRB_p  \
# index
# FCAImmP7179369-AAACCTGAGCCCAATT  FCAImmP7179369     False     False
# FCAImmP7179369-AAACCTGAGCCTATGT  FCAImmP7179369     False     False
# FCAImmP7179369-AAACCTGAGTCGCCGT  FCAImmP7179369     False     False
# FCAImmP7179369-AAACCTGCAGCATGAG  FCAImmP7179369     False     False
# FCAImmP7179369-AAACCTGGTCTCCCTA  FCAImmP7179369     False     False
#
#                                  is_TRA_np  is_TRB_np  ... IR_VDJ_2_j_gene  \
# ...

# %%
path_tcr_anno = '06_tcr_annotation_data.h5ad'
adata = sc.read_h5ad(path_tcr_anno)

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 10954 × 5000
# ...

# %%
print('Annotations per Cell: ')
adata.var_names_make_unique()
adata.obs.head(10)
# Out:
# Annotations per Cell:
#                                           Sample donor organ sort method  \
# index
# FCAImmP7292030-AAACCTGGTACAGACG  F29_TH_45P_5GEX   F29    TH  45P   5GEX
# FCAImmP7292030-AAACCTGTCCCTTGTG  F29_TH_45P_5GEX   F29    TH  45P   5GEX
# FCAImmP7292030-AAACGGGTCAAGCCTA  F29_TH_45P_5GEX   F29    TH  45P   5GEX
# FCAImmP7292030-AAACGGGTCGACGGAA  F29_TH_45P_5GEX   F29    TH  45P   5GEX
# FCAImmP7292030-AAACGGGTCTTAACCT  F29_TH_45P_5GEX   F29    TH  45P   5GEX
# FCAImmP7292030-AAAGATGGTCATACTG  F29_TH_45P_5GEX   F29    TH  45P   5GEX
# FCAImmP7292030-AAAGATGTCAACACCA  F29_TH_45P_5GEX   F29    TH  45P   5GEX
# FCAImmP7292030-AAAGATGTCATAGCAC  F29_TH_45P_5GEX   F29    TH  45P   5GEX
# FCAImmP7292030-AAAGCAAAGACAAGCC  F29_TH_45P_5GEX   F29    TH  45P   5GEX
# FCAImmP7292030-AAAGCAACAATGGACG  F29_TH_45P_5GEX   F29    TH  45P   5GEX
#
#                                            file  is_TRA_p  is_TRB_p  \
# index
# ...

# %%
sc.tl.pca(adata, svd_solver='arpack')

# %%
sc.pl.pca(adata, color='Sample')

# %%
sc.pl.pca_variance_ratio(adata, log=True)

# %%
sc.pp.normalize_per_cell(adata, counts_per_cell_after=1e4)

# %%
sc.pp.log1p(adata)

# %%
adata.raw = adata

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 10954 × 5000
# ...

# %%
sc.pl.highly_variable_genes(adata)

# %%
data = adata[:, adata.var['highly_variable']]

# %%
sc.pl.pca(adata, color='Sample', components = ['1,2','3,4','5,6','7,8'], ncols=2)

# %%
sc.pl.pca_loadings(adata, components=[1,2,3,4,5,6,7,8])

# %%
sc.tl.tsne(adata, n_pcs = 30)

# %%
sc.pl.tsne(adata, color='Sample')

# %%
sc.pp.neighbors(adata, n_pcs = 40, n_neighbors = 20)
use_rep='X'

# %%
sc.tl.umap(adata)

# %%
sc.pl.umap(adata, color='Sample')

# %%
sc.pl.umap(adata, color=["Age","cell types","Source","clonotype"])

# %%
path_tcr_anno = '06_tcr_annotation_data.h5ad'
adata = sc.read_h5ad(path_tcr_anno)
sc.pp.log1p(adata)
sc.pp.neighbors(adata, n_neighbors=20, use_rep='X', method='gauss')

# %%
sc.tl.diffmap(adata)
adata.uns['iroot'] = 36
sc.tl.dpt(adata, n_branchings=1, n_dcs=10)
sc.pl.diffmap(adata, color=['Age', 'cell types', 'clonotype'])
allow_kendall_tau_shift=False
# Out:
# WARNING: shifting branching point away from maximal kendall-tau correlation (suppress this with `allow_kendall_tau_shift=False`)

# %%
sc.pl.dpt_groups_pseudotime(adata)
# Out:
# /Users/chengshiluo/opt/anaconda3/lib/python3.8/site-packages/scanpy/plotting/_utils.py:118: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   X = X[:, None]

# %%
sc.pl.dpt_timeseries(adata)
# Out:
# WARNING: Plotting more than 100 genes might take some while, consider selecting only highly variable genes, for example.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: float() argument must be a string or a number, not 'csc_matrix'
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-e3677889bcc8> in <module>
# ----> 1 sc.pl.dpt_timeseries(adata)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/scanpy/plotting/_tools/__init__.py in dpt_timeseries(adata, color_map, show, save, as_heatmap)
#     214     if as_heatmap:
#     215         # plot time series as heatmap, as in Haghverdi et al. (2016), Fig. 1d
# --> 216         timeseries_as_heatmap(
#     217             adata.X[adata.obs['dpt_order_indices'].values],
# ...

# %%
sc.pl.umap(adata, color='cell types', legend_loc='on data')

# %%
adata.obs['cell types'].value_counts()
# Out:
# CD4+T         2148
# CD8+T         1797
# αβT(entry)    1589
# DP(Q)         1208
# CD8αα(I)       866
# Treg(diff)     829
# T(agonist)     768
# CD8αα(II)      563
# DP(P)          531
# Treg           393
# Th17            84
# DN(Q)           84
# NKT             31
# DN(P)           24
# γδT             21
# DN(early)       18
# Name: cell types, dtype: int64

# %%
sc.pl.umap(adata, color='cell types', groups='DP(Q)')

# %%
sc.pl.umap(adata, color='cell types', groups='DP(P)')
